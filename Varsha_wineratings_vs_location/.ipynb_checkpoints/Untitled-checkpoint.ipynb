# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %%
rawWineDF = pd.read_csv("../Data/winemag-data-130k-v2.csv")
rawWineDF['Year'] = ''
##############################################################################
def GetYear(strn):
    yearValue = 'Nan'
    try: yearValue = int(re.findall('(\d{4})', strn)[0])
    except: yearValue = 'Nan' 
    return yearValue
##############################################################################
rawWineDF.Year = rawWineDF.apply(lambda row: GetYear(row.title),axis=1)
##############################################################################
rawWineDF.to_csv('../Data/WineData.csv')
wineDF = rawWineDF[['country', 'description', 'designation', 'points', 'price', 'province', 'region_1', 'title', 'variety', 'winery', 'Year']]
wineDF = wineDF.rename(columns={'region_1': 'region'})

# %%
wineDF.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                 region                                              title  \
# 0                 Etna                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1                  NaN      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2    Willamette Valley      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3  Lake Michigan Shore  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4    Willamette Valley  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery Year
# 0     White Blend              Nicosia  Nan
# 1  Portuguese Red  Quinta dos Avidagos  Nan
# 2      Pinot Gris            Rainstorm  Nan
# 3        Riesling           St. Julian  Nan
# 4      Pinot Noir         Sweet Cheeks  Nan

# %%
wineDF.fillna("Unlisted")
wineDF.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                 region                                              title  \
# 0                 Etna                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1                  NaN      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2    Willamette Valley      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3  Lake Michigan Shore  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4    Willamette Valley  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery Year
# 0     White Blend              Nicosia  Nan
# 1  Portuguese Red  Quinta dos Avidagos  Nan
# 2      Pinot Gris            Rainstorm  Nan
# 3        Riesling           St. Julian  Nan
# 4      Pinot Noir         Sweet Cheeks  Nan

# %%
df = wineDF.dropna(how='any')
df.head()
# Out:
#   country                                        description  \
# 3      US  Pineapple rind, lemon pith and orange blossom ...
# 4      US  Much like the regular bottling from 2012, this...
# 5   Spain  Blackberry and raspberry aromas show a typical...
# 6   Italy  Here's a bright, informal red that opens with ...
# 9  France  This has great depth of flavor with its fresh ...
#
#                           designation  points  price           province  \
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                        Ars In Vitro      87   15.0     Northern Spain
# 6                             Belsito      87   16.0  Sicily & Sardinia
# 9                         Les Natures      87   27.0             Alsace
#
#                 region                                              title  \
# 3  Lake Michigan Shore  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4    Willamette Valley  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5              Navarra  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# 6             Vittoria   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 9               Alsace  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...
#
#               variety              winery Year
# 3            Riesling          St. Julian  Nan
# 4          Pinot Noir        Sweet Cheeks  Nan
# 5  Tempranillo-Merlot              Tandem  Nan
# 6            Frappato     Terre di Giurfo  Nan
# 9          Pinot Gris  Jean-Baptiste Adam  Nan

# %%
df.count()
# Out:
# country        70175
# description    70175
# designation    70175
# points         70175
# price          70175
# province       70175
# region         70175
# title          70175
# variety        70175
# winery         70175
# Year           70175
# dtype: int64

# %%
df.dtypes
# Out:
# country         object
# description     object
# designation     object
# points           int64
# price          float64
# province        object
# region          object
# title           object
# variety         object
# winery          object
# Year            object
# dtype: object

# %%
wine_df = wineDF.drop_duplicates(subset=['country', 'description', 'designation',
                               'points', 'price', 'province', 'region', 'title', 'variety', 'winery'], keep=False)
wine_df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                 region                                              title  \
# 0                 Etna                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1                  NaN      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2    Willamette Valley      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3  Lake Michigan Shore  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4    Willamette Valley  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery Year
# 0     White Blend              Nicosia  Nan
# 1  Portuguese Red  Quinta dos Avidagos  Nan
# 2      Pinot Gris            Rainstorm  Nan
# 3        Riesling           St. Julian  Nan
# 4      Pinot Noir         Sweet Cheeks  Nan

# %%
wine_df.count()
# Out:
# country        109950
# description    110005
# designation     78380
# points         110005
# price          102211
# province       109950
# region          92132
# title          110005
# variety        110004
# winery         110005
# Year           110005
# dtype: int64
